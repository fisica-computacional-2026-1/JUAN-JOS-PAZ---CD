# %% [markdown]
# # W04A — Cómo “piensa” el motor: **EXPLAIN**, cardinalidad y performance (DuckDB)
#
# **Objetivo:** aprender a **leer planes de ejecución** y detectar los 3 problemas más comunes en analítica:
# 1) **scan enorme** (lees más de lo que necesitas),
# 2) **JOIN que infló** (cardinalidad mal controlada),
# 3) **agregación cara** (filtro tarde / columnas de más).

# %% [markdown]
# ## Bibliografía (W04 en general)
#
# ### Libro guía — **DDIA (Martin Kleppmann)**
# - **Capítulo 3: Storage and Retrieval**
#   Úsalo para: *OLTP vs OLAP, por qué en analítica importa el ancho de banda, column-oriented storage, y por qué el layout/índices cambian el costo de las consultas.*
#
#
# ### Documentación práctica — DuckDB
# - `EXPLAIN` / `EXPLAIN ANALYZE` (planes y cardinalidad)
# - Profiling con `PRAGMA enable_profiling`
# - Índices (`CREATE INDEX`) y tipos de índices (zonemap / ART)

# %%
from pathlib import Path
import duckdb

PROJECT_ROOT = Path(".").resolve()

if PROJECT_ROOT.name.lower() == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

RAW_DIR = PROJECT_ROOT / "data" / "raw"

# Base separada para evitar conflicto con otro kernel abierto
DB_PATH = PROJECT_ROOT / "data" / "exoplanets_w04a.duckdb"

ART_DIR = PROJECT_ROOT / "artifacts"
DOCS_DIR = PROJECT_ROOT / "docs"

RAW_DIR.mkdir(parents=True, exist_ok=True)
ART_DIR.mkdir(parents=True, exist_ok=True)
DOCS_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("RAW_DIR:", RAW_DIR)
print("DB_PATH:", DB_PATH)

con = duckdb.connect(str(DB_PATH))

raw_csv = RAW_DIR / "pscomppars.csv"

print("raw_csv:", raw_csv)
print("Existe raw_csv:", raw_csv.exists())

if not raw_csv.exists():
    raise FileNotFoundError(
        f"No encuentro {raw_csv}. Revisa que el CSV esté en data/raw/pscomppars.csv"
    )

def sql_quote(s: str) -> str:
    return "'" + s.replace("'", "''") + "'"

con.execute(f'''
CREATE OR REPLACE VIEW raw_ps AS
SELECT * FROM read_csv_auto({sql_quote(str(raw_csv.resolve()))})
''')

# Si ya tienes Silver/Facts de W03B, perfecto. Si no, los construimos rápido aquí (idéntico a W03B).
con.execute("DROP TABLE IF EXISTS silver_planet")
con.execute('''
CREATE TABLE silver_planet AS
SELECT
  pl_name,
  hostname,
  discoverymethod,
  disc_year,
  sy_snum,
  sy_pnum,
  sy_dist,
  ra,
  dec,
  pl_orbper,
  pl_rade,
  pl_bmasse,
  pl_eqt,
  st_teff,
  st_rad,
  st_mass
FROM raw_ps
WHERE pl_name IS NOT NULL
  AND hostname IS NOT NULL
  AND (disc_year IS NULL OR (disc_year BETWEEN 1980 AND 2026))
  AND (pl_rade  IS NULL OR (pl_rade  > 0 AND pl_rade  <= 30))
  AND (pl_bmasse IS NULL OR (pl_bmasse > 0))
''')

con.execute("DROP TABLE IF EXISTS dim_host_full")
con.execute('''
CREATE TABLE dim_host_full AS
SELECT
  hostname,
  MAX(sy_dist)  AS sy_dist,
  MAX(ra)       AS ra,
  MAX(dec)      AS dec,
  MAX(st_teff)  AS st_teff,
  MAX(st_rad)   AS st_rad,
  MAX(st_mass)  AS st_mass
FROM silver_planet
GROUP BY hostname
''')

con.execute("DROP TABLE IF EXISTS fact_planet")
con.execute('''
CREATE TABLE fact_planet AS
SELECT DISTINCT
  pl_name,
  hostname,
  discoverymethod,
  disc_year,
  pl_orbper,
  pl_rade,
  pl_bmasse,
  pl_eqt
FROM silver_planet
''')

con.sql("SELECT COUNT(*) AS n_fact, COUNT(DISTINCT pl_name) AS n_pl, COUNT(DISTINCT hostname) AS n_hosts FROM fact_planet").show()
# Out:
# PROJECT_ROOT: C:\Users\USUARIO WINDOWS\CODIGOS\PAZ CD
# RAW_DIR: C:\Users\USUARIO WINDOWS\CODIGOS\PAZ CD\data\raw
# DB_PATH: C:\Users\USUARIO WINDOWS\CODIGOS\PAZ CD\data\exoplanets_w04a.duckdb
# raw_csv: C:\Users\USUARIO WINDOWS\CODIGOS\PAZ CD\data\raw\pscomppars.csv
# Existe raw_csv: True
# ┌────────┬───────┬─────────┐
# │ n_fact │ n_pl  │ n_hosts │
# │ int64  │ int64 │  int64  │
# ├────────┼───────┼─────────┤
# │   6286 │  6286 │    4705 │
# └────────┴───────┴─────────┘

# %% [markdown]
# ## 1) Qué vamos a mirar en un plan (lectura rápida)
#
# Cuando mires `EXPLAIN`, busca:
# - **SCAN**: ¿está leyendo demasiadas filas/columnas?
# - **FILTER**: ¿se aplica temprano o tarde?
# - **JOIN**: ¿qué tipo? (HASH JOIN típico en analítica)
# - **GROUP BY**: ¿cuántas filas entran?
# - **CARDINALIDAD**: cuántas filas pasan por cada operador
#
# `EXPLAIN` = estimado
# `EXPLAIN ANALYZE` = real (ejecuta y muestra cardinalidad real + tiempos)

# %%
# TU TURNO 1: pega aquí una consulta tipo "métrica" y mira su plan.
# Debe tener: WHERE + GROUP BY (como en W02A).
# Ejemplo de idea: por disc_year o por discoverymethod.

q = '''
-- TODO: tu SQL
SELECT 1;
'''

con.sql("EXPLAIN " + q).show()
# Si corre rápido:
# con.sql("EXPLAIN ANALYZE " + q).show()
# Out:
# ┌───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │  explain_key  │                                                                                                                                                     explain_value                                                                                                                                                      │
# │    varchar    │                                                                                                                                                        varchar                                                                                                                                                         │
# ├───────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physical_plan │ ┌───────────────────────────┐\n│         PROJECTION        │\n│    ────────────────────   │\n│             1             │\n│                           │\n│           ~1 row          │\n└─────────────┬─────────────┘\n┌─────────────┴─────────────┐\n│         DUMMY_SCAN        │\n└───────────────────────────┘\n │
# └───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# TU TURNO 2: escribe dos consultas equivalentes:
# A) con SELECT * y B) con solo 3 columnas.
# Luego compara sus planes.

qA = '''
-- TODO: SELECT * ...
SELECT 1;
'''
qB = '''
-- TODO: SELECT col1, col2, col3 ...
SELECT 1;
'''

con.sql("EXPLAIN " + qA).show()
con.sql("EXPLAIN " + qB).show()
# Out:
# ┌───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │  explain_key  │                                                                                                                                                     explain_value                                                                                                                                                      │
# │    varchar    │                                                                                                                                                        varchar                                                                                                                                                         │
# ├───────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physical_plan │ ┌───────────────────────────┐\n│         PROJECTION        │\n│    ────────────────────   │\n│             1             │\n│                           │\n│           ~1 row          │\n└─────────────┬─────────────┘\n┌─────────────┴─────────────┐\n│         DUMMY_SCAN        │\n└───────────────────────────┘\n │
# └───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │  explain_key  │                                                                                                                                                     explain_value                                                                                                                                                      │
# │    varchar    │                                                                                                                                                        varchar                                                                                                                                                         │
# ├───────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physical_plan │ ┌───────────────────────────┐\n│         PROJECTION        │\n│    ────────────────────   │\n│             1             │\n│                           │\n│           ~1 row          │\n└─────────────┬─────────────┘\n┌─────────────┴─────────────┐\n│         DUMMY_SCAN        │\n└───────────────────────────┘\n │
# └───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# TU TURNO 3: valida un JOIN sano con evidencia
# 1) arma un JOIN fact_planet + dim_host_full (LEFT JOIN)
# 2) muestra EXPLAIN
# 3) muestra n_fact vs n_join

q_join = '''
-- TODO: tu SQL de join + group by (o join simple)
SELECT 1;
'''

con.sql("EXPLAIN " + q_join).show()

n_fact = con.sql("SELECT COUNT(*) FROM fact_planet").fetchone()[0]
n_join = con.sql('''
-- TODO: cuenta filas del join (LEFT JOIN)
SELECT 1;
''').fetchone()[0]

n_fact, n_join
# Out:
# ┌───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │  explain_key  │                                                                                                                                                     explain_value                                                                                                                                                      │
# │    varchar    │                                                                                                                                                        varchar                                                                                                                                                         │
# ├───────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ physical_plan │ ┌───────────────────────────┐\n│         PROJECTION        │\n│    ────────────────────   │\n│             1             │\n│                           │\n│           ~1 row          │\n└─────────────┬─────────────┘\n┌─────────────┴─────────────┐\n│         DUMMY_SCAN        │\n└───────────────────────────┘\n │
# └───────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# (6286, 1)

# %% [markdown]
# ## Para entregar (W04A) — mesurado
#
# ### En clase
# 1) `docs/w04a_perf_report.md` con:
#    - 2 planes (`EXPLAIN`) pegados (consulta tuya + JOIN)
#    - 2 conclusiones cortas (2–3 líneas cada una) sobre:
#      - dónde está el costo (SCAN/JOIN/GROUP BY)
#      - qué mejorarías (leer menos columnas, filtrar antes, etc.)
# 2) `docs/decisions_log.md`: 1 decisión:
#    - “Reescribí una consulta para reducir costo” + evidencia (plan antes/después o conteo).
#
# ### Tarea
# 1) Ejecuta `EXPLAIN ANALYZE` sobre 1 consulta y pega el resultado.
# 2) Exporta a `artifacts/` un archivo de evidencia:
#    - `artifacts/w04a_explain_q1.txt` (copiar/pegar plan a texto está bien)

# %% [markdown]
# ## Reflexión (bitácora)
# - ¿Qué parte del plan te costó más interpretar?
# - Si el dataset creciera 100×, ¿qué operador crees que empeora primero (SCAN/JOIN/GROUP BY) y por qué?

# %%
q = """
SELECT
  FLOOR(disc_year / 10) * 10 AS decade,
  COUNT(*) AS n_planets,
  ROUND(AVG(pl_orbper), 2) AS avg_orbital_period
FROM fact_planet
WHERE disc_year IS NOT NULL
  AND disc_year >= 2000
  AND pl_orbper IS NOT NULL
GROUP BY decade
ORDER BY decade ASC
"""

q_join = """
SELECT
  CASE
    WHEN h.st_teff < 5000 THEN 'cool_star'
    WHEN h.st_teff BETWEEN 5000 AND 6500 THEN 'solar_like_star'
    ELSE 'hot_star'
  END AS stellar_group,
  COUNT(*) AS n_planets,
  ROUND(AVG(f.pl_rade), 2) AS avg_radius
FROM fact_planet f
JOIN dim_host_full h
  ON f.hostname = h.hostname
WHERE h.st_teff IS NOT NULL
  AND f.pl_rade IS NOT NULL
GROUP BY stellar_group
ORDER BY n_planets DESC
"""

# %%
def get_explain_text(sql_query):
    result = con.sql("EXPLAIN " + sql_query).fetchall()

    if len(result) > 0 and len(result[0]) >= 2:
        return result[0][1]

    return "\n".join(str(row) for row in result)


plan_q = get_explain_text(q)
plan_join = get_explain_text(q_join)

print("Plan consulta métrica:")
print(plan_q)

print("\n" + "="*80 + "\n")

print("Plan JOIN:")
print(plan_join)
# Out:
# Plan consulta métrica:
# ┌───────────────────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │  (floor((exoplanets_w04a  │
# │     .main.fact_planet     │
# │.disc_year / 10)) * 10) ASC│
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             0             │
# │         n_planets         │
# │     avg_orbital_period    │
# │                           │
# │         ~628 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │         Groups: #0        │
# │                           │
# │        Aggregates:        │
# │        count_star()       │
# │          avg(#1)          │
# │                           │
# │         ~628 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │           decade          │
# │         pl_orbper         │
# │                           │
# │        ~1,257 rows        │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         SEQ_SCAN          │
# │    ────────────────────   │
# │     Table: fact_planet    │
# │   Type: Sequential Scan   │
# │                           │
# │        Projections:       │
# │         disc_year         │
# │         pl_orbper         │
# │                           │
# │          Filters:         │
# │    disc_year>=2000 AND    │
# │  (disc_year IS NOT NULL)  │
# │  (pl_orbper IS NOT NULL)  │
# │                           │
# │        ~1,257 rows        │
# └───────────────────────────┘
#
#
# ================================================================================
#
# Plan JOIN:
# ┌───────────────────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │__internal_decompress_strin│
# │           g(#0)           │
# │             #1            │
# │             #2            │
# │                           │
# │          ~0 rows          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │     count_star() DESC     │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │__internal_compress_string_│
# │        uhugeint(#0)       │
# │             #1            │
# │             #2            │
# │                           │
# │         ~125 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             0             │
# │         n_planets         │
# │         avg_radius        │
# │                           │
# │         ~125 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │__internal_decompress_strin│
# │           g(#0)           │
# │             #1            │
# │             #2            │
# │                           │
# │         ~125 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │         Groups: #0        │
# │                           │
# │        Aggregates:        │
# │        count_star()       │
# │          avg(#1)          │
# │                           │
# │         ~125 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │__internal_compress_string_│
# │   uhugeint(CASE  WHEN (   │
# │ (st_teff < 5000.0)) THEN (│
# │    'cool_star') WHEN ((   │
# │  (st_teff >= 5000.0) AND  │
# │ (st_teff <= 6500.0))) THEN│
# │  ('solar_like_star') ELSE │
# │      'hot_star' END)      │
# │          pl_rade          │
# │                           │
# │         ~251 rows         │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         HASH_JOIN         │
# │    ────────────────────   │
# │      Join Type: INNER     │
# │                           │
# │        Conditions:        ├──────────────┐
# │    hostname = hostname    │              │
# │                           │              │
# │         ~251 rows         │              │
# └─────────────┬─────────────┘              │
# ┌─────────────┴─────────────┐┌─────────────┴─────────────┐
# │         SEQ_SCAN          ││         SEQ_SCAN          │
# │    ────────────────────   ││    ────────────────────   │
# │     Table: fact_planet    ││    Table: dim_host_full   │
# │   Type: Sequential Scan   ││   Type: Sequential Scan   │
# │                           ││                           │
# │        Projections:       ││        Projections:       │
# │          hostname         ││          hostname         │
# │          pl_rade          ││          st_teff          │
# │                           ││                           │
# │          Filters:         ││          Filters:         │
# │   (pl_rade IS NOT NULL)   ││   (st_teff IS NOT NULL)   │
# │                           ││                           │
# │        ~1,257 rows        ││         ~941 rows         │
# └───────────────────────────┘└───────────────────────────┘

# %%
explain_analyze_result = con.sql("EXPLAIN ANALYZE " + q).fetchall()

print(explain_analyze_result[0][1])
# Out:
# ┌─────────────────────────────────────┐
# │┌───────────────────────────────────┐│
# ││    Query Profiling Information    ││
# │└───────────────────────────────────┘│
# └─────────────────────────────────────┘
# EXPLAIN ANALYZE  SELECT   FLOOR(disc_year / 10) * 10 AS decade,   COUNT(*) AS n_planets,   ROUND(AVG(pl_orbper), 2) AS avg_orbital_period FROM fact_planet WHERE disc_year IS NOT NULL   AND disc_year >= 2000   AND pl_orbper IS NOT NULL GROUP BY decade ORDER BY decade ASC
# ┌────────────────────────────────────────────────┐
# │┌──────────────────────────────────────────────┐│
# ││              Total Time: 0.0125s             ││
# │└──────────────────────────────────────────────┘│
# └────────────────────────────────────────────────┘
# ┌───────────────────────────┐
# │           QUERY           │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │      EXPLAIN_ANALYZE      │
# │    ────────────────────   │
# │           0 rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │          ORDER_BY         │
# │    ────────────────────   │
# │  (floor((exoplanets_w04a  │
# │     .main.fact_planet     │
# │.disc_year / 10)) * 10) ASC│
# │                           │
# │           3 rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │             0             │
# │         n_planets         │
# │     avg_orbital_period    │
# │                           │
# │           3 rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │       HASH_GROUP_BY       │
# │    ────────────────────   │
# │         Groups: #0        │
# │                           │
# │        Aggregates:        │
# │        count_star()       │
# │          avg(#1)          │
# │                           │
# │           3 rows          │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         PROJECTION        │
# │    ────────────────────   │
# │           decade          │
# │         pl_orbper         │
# │                           │
# │         5,919 rows        │
# │          (0.00s)          │
# └─────────────┬─────────────┘
# ┌─────────────┴─────────────┐
# │         TABLE_SCAN        │
# │    ────────────────────   │
# │     Table: fact_planet    │
# │   Type: Sequential Scan   │
# │                           │
# │        Projections:       │
# │         disc_year         │
# │         pl_orbper         │
# │                           │
# │          Filters:         │
# │    disc_year>=2000 AND    │
# │  (disc_year IS NOT NULL)  │
# │  (pl_orbper IS NOT NULL)  │
# │                           │
# │         5,919 rows        │
# │          (0.00s)          │
# └───────────────────────────┘

# %%
ART_DIR.mkdir(parents=True, exist_ok=True)

out_plan = ART_DIR / "w04a_explain_q1.txt"

content = f"""
PLAN CONSULTA MÉTRICA
=====================

{plan_q}


PLAN CONSULTA CON JOIN
======================

{plan_join}


EXPLAIN ANALYZE CONSULTA MÉTRICA
================================

{explain_analyze_result[0][1]}
"""

out_plan.write_text(content, encoding="utf-8")

print("Archivo exportado:", out_plan)
# Out:
# Archivo exportado: C:\Users\USUARIO WINDOWS\CODIGOS\PAZ CD\artifacts\w04a_explain_q1.txt
